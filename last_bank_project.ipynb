# %%
import pandas as pd
import numpy as np
from scipy import stats

# %% [markdown]
# ## Import file

# %%
bank_df = pd.read_excel("bank_deposit.xlsx")
bank_df.head()
# bank_df.shape # 11,222 rows, columns 17
# Out:
#    age      job   marital  education default  balance housing loan    contact  \
# 0   95  retired  divorced    primary      no   2282.0      no   no  telephone
# 1   95  retired   married  secondary      no      0.0      no   no  telephone
# 2   94  retired  divorced  secondary      no   1234.0      no   no   cellular
# 3   93  retired   married    unknown      no    775.0      no   no   cellular
# 4   93  retired   married    unknown      no    775.0      no   no   cellular
#
#     day month  duration  campaign  pdays  previous poutcome  \
# 0  21.0   apr     207.0      17.0   -1.0       0.0  unknown
# 1   1.0   oct     215.0       1.0   -1.0       0.0  unknown
# 2   3.0   mar     212.0       1.0   -1.0       0.0  unknown
# 3  22.0   jul     860.0       2.0  177.0       7.0  success
# 4   4.0   aug     476.0       2.0   13.0       9.0  success
#
#   Bank deposit(target)
# 0                  yes
# 1                   no
# 2                   no
# 3                  yes
# 4                  yes

# %% [markdown]
# ## Assessement of anomalies

# %%
bank_df.isna().sum()
# education - replace with unknown as is an option in the categories
# 6 NA categories all in same rows (housing, default, balance,contact)
# Out:
# age                      0
# job                      0
# marital                  6
# education               27
# default                  6
# balance                  6
# housing                  6
# loan                    12
# contact                  6
# day                      6
# month                    8
# duration                 8
# campaign                 8
# pdays                    8
# previous                 6
# poutcome                 0
# Bank deposit(target)     0
# dtype: int64

# %%
# To drop the rows that contained NAN in the contact column, as cannot be contacted and thus useless data
#bank_df= bank_df[bank_df['contact'].isna()]
#bank_df

# %%
bank_df[bank_df.isna().any(axis=1)]
# Out:
#      age           job   marital  education default  balance housing loan  \
# 21    86       retired  divorced        NaN      no      0.0      no   no
# 22    86       retired  divorced        NaN      no    157.0      no   no
# 23    86       retired    single        NaN      no    614.0      no   no
# 24    86       retired   married        NaN      no   1817.0      no   no
# 25    86       retired   married        NaN      no   1503.0      no   no
# 26    86       retired   married        NaN      no   5236.0      no   no
# 27    86       retired   married        NaN      no   1255.0      no   no
# 28    86       retired   married        NaN      no   1255.0      no   no
# 29    85       retired   married        NaN      no  12114.0      no   no
# 30    85       retired  divorced        NaN      no   7613.0      no   no
# 31    85       retired   married        NaN      no     98.0      no   no
# 32    85       retired   married        NaN      no   1934.0      no   no
# 33    85       retired   married        NaN      no   1255.0      no   no
# 34    84       retired  divorced        NaN      no    639.0      no   no
# 35    84       retired   married        NaN      no   1702.0      no   no
# 36    84  entrepreneur   married        NaN      no      0.0      no   no
# 37    84       retired   married        NaN      no   1791.0      no  NaN
# 38    84       retired   married        NaN      no  81204.0      no  NaN
# 39    84       retired  divorced        NaN      no   2619.0      no  NaN
# 40    84       retired   married        NaN      no  81204.0      no  NaN
# 41    84       retired  divorced        NaN      no    639.0      no  NaN
# 42    84       retired  divorced    primary      no   1680.0      no  NaN
# 134   80     housemaid       NaN        NaN     NaN      NaN     NaN  NaN
# 135   80       retired       NaN        NaN     NaN      NaN     NaN  NaN
# 136   80       retired       NaN        NaN     NaN      NaN     NaN  NaN
# 137   80       retired       NaN        NaN     NaN      NaN     NaN  NaN
# 138   80       retired       NaN        NaN     NaN      NaN     NaN  NaN
# 139   80       retired       NaN        NaN     NaN      NaN     NaN  NaN
# 232   77       retired   married  secondary      no   4112.0      no   no
# 233   77       retired   married   tertiary      no   7802.0      no   no
#
#        contact   day month    duration  campaign  pdays  previous poutcome  \
# 21   telephone  26.0   aug       189.0       1.0   -1.0       0.0  unknown
# 22   telephone   7.0   sep       147.0       1.0   -1.0       0.0  unknown
# 23   telephone   9.0   dec       595.0       1.0   -1.0       0.0  unknown
# 24    cellular  16.0   mar       272.0       3.0   -1.0       0.0  unknown
# 25   telephone  18.0   mar       165.0       3.0  101.0       1.0    other
# 26   telephone   1.0   apr       558.0       2.0   -1.0       0.0  unknown
# 27   telephone  14.0   jul       247.0       1.0  180.0       3.0  success
# 28    cellular  14.0   oct       192.0       2.0   92.0       4.0  success
# 29   telephone  12.0   feb       165.0       2.0   -1.0       0.0  unknown
# 30    cellular  18.0   feb       355.0       3.0   -1.0       0.0  unknown
# 31        ghjk  30.0   apr       416.0       1.0   -1.0       0.0  unknown
# 32   telephone  12.0   jan       140.0       1.0   -1.0       0.0  unknown
# 33    cellular  15.0   jan       233.0       3.0   -1.0       0.0  unknown
# 34   telephone  18.0   may       353.0       3.0   -1.0       0.0  unknown
# 35   telephone  26.0   aug       185.0       1.0   -1.0       0.0  unknown
# 36   telephone  30.0   sep       992.0       2.0   -1.0       0.0  unknown
# 37   telephone  30.0   oct        62.0       3.0   -1.0       0.0  unknown
# 38   telephone  28.0   dec  20000000.0       1.0  313.0       2.0    other
# 39   telephone   8.0   feb       145.0       2.0  115.0       2.0  failure
# 40   telephone   1.0   apr       390.0       1.0   94.0       3.0  success
# 41   telephone  18.0   may       353.0       3.0   -1.0       0.0  unknown
# 42   telephone   6.0   sep       113.0       5.0   97.0       3.0    other
# 134        NaN   NaN   NaN         NaN       NaN    NaN       NaN  failure
# 135        NaN   NaN   NaN         NaN       NaN    NaN       NaN  unknown
# 136        NaN   NaN   NaN         NaN       NaN    NaN       NaN  success
# 137        NaN   NaN   NaN         NaN       NaN    NaN       NaN  unknown
# 138        NaN   NaN   NaN         NaN       NaN    NaN       NaN  failure
# 139        NaN   NaN   NaN         NaN       NaN    NaN       NaN  success
# 232  telephone  26.0   NaN         NaN       NaN    NaN       2.0  success
# 233  telephone   1.0   NaN         NaN       NaN    NaN       0.0  unknown
#
#     Bank deposit(target)
# 21                   yes
# 22                    no
# 23                   yes
# 24                    no
# 25                    no
# 26                   yes
# 27                   yes
# 28                    no
# 29                   yes
# 30                   yes
# 31                   yes
# 32                    no
# 33                   yes
# 34                   yes
# 35                    no
# 36                   yes
# 37                    no
# 38                   yes
# 39                    no
# 40                   yes
# 41                   yes
# 42                    no
# 134                   no
# 135                   no
# 136                  yes
# 137                   no
# 138                  yes
# 139                  yes
# 232                  yes
# 233                  yes

# %%
bank_df.describe()
# Out:
#                 age       balance           day      duration      campaign  \
# count  11222.000000  1.121600e+04  11216.000000  1.121400e+04  11214.000000
# mean      56.411068  7.966974e+03     15.786912  2.040672e+03      2.737739
# std        6.141462  6.421456e+05      8.336913  1.888620e+05      2.854410
# min       50.000000 -4.057000e+03      1.000000  0.000000e+00      1.000000
# 25%       52.000000  1.080000e+02      8.000000  1.020000e+02      1.000000
# 50%       55.000000  6.275000e+02     16.000000  1.760000e+02      2.000000
# 75%       58.000000  2.031750e+03     21.000000  3.160000e+02      3.000000
# max       95.000000  6.800000e+07     31.000000  2.000000e+07     43.000000
#
#               pdays      previous
# count  11214.000000  11216.000000
# mean      35.118245      0.558934
# std       90.776604      1.741345
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# 75%       -1.000000      0.000000
# max      792.000000     37.000000

# %%
# Droping customer index 38 because it is a potential duplicate with corrupted "duration" value.
## this can be done with the Remove_outlier function at the bottom thus commented out
# bank_df = bank_df.drop(index=38)

# %%
# Dropped the rows that contained NAN in the contact column.
bank_df= bank_df[bank_df['contact'].notna()]
bank_df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       95       retired  divorced    primary      no   2282.0      no   no
# 1       95       retired   married  secondary      no      0.0      no   no
# 2       94       retired  divorced  secondary      no   1234.0      no   no
# 3       93       retired   married    unknown      no    775.0      no   no
# 4       93       retired   married    unknown      no    775.0      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 11217   50  entrepreneur  divorced   tertiary      no    315.0      no   no
# 11218   50    management   married   tertiary      no   2881.0      no   no
# 11219   50    technician  divorced  secondary      no      0.0     yes   no
# 11220   50      services   married  secondary      no   2376.0     yes   no
# 11221   50    management   married   tertiary      no   8205.0     yes   no
#
#          contact   day month  duration  campaign  pdays  previous poutcome  \
# 0      telephone  21.0   apr     207.0      17.0   -1.0       0.0  unknown
# 1      telephone   1.0   oct     215.0       1.0   -1.0       0.0  unknown
# 2       cellular   3.0   mar     212.0       1.0   -1.0       0.0  unknown
# 3       cellular  22.0   jul     860.0       2.0  177.0       7.0  success
# 4       cellular   4.0   aug     476.0       2.0   13.0       9.0  success
# ...          ...   ...   ...       ...       ...    ...       ...      ...
# 11217   cellular  12.0   jul     101.0       2.0  185.0       2.0  failure
# 11218   cellular   5.0   aug     510.0       2.0    2.0       5.0    other
# 11219   cellular  13.0   aug     120.0       2.0   91.0       6.0  failure
# 11220   cellular  24.0   sep     395.0       1.0   -1.0       0.0  unknown
# 11221  telephone  25.0   oct     293.0       3.0  508.0       1.0    other
#
#       Bank deposit(target)
# 0                      yes
# 1                       no
# 2                       no
# 3                      yes
# 4                      yes
# ...                    ...
# 11217                   no
# 11218                   no
# 11219                   no
# 11220                  yes
# 11221                   no
#
# [11216 rows x 17 columns]

# %%
#Checking for duplicate rows
bank_df[bank_df.duplicated(keep=False)].sort_values(by=['balance'], ascending = True)
# Out:
#       age            job  marital  education default  balance housing loan  \
# 3713   57  self-employed  married   tertiary     yes  -3313.0     yes  yes
# 3753   57  self-employed  married   tertiary     yes  -3313.0     yes  yes
# 9209   51   entrepreneur  married  secondary     yes  -2082.0      no  yes
# 9647   51   entrepreneur  married  secondary     yes  -2082.0      no  yes
# 8203   52     management  married   tertiary      no  -1224.0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 305    75        retired  married  secondary      no  26452.0      no   no
# 3944   57     technician  married   tertiary      no  27069.0      no  yes
# 3697   57     technician  married   tertiary      no  27069.0      no  yes
# 1356   60        retired  married    primary      no  71188.0      no   no
# 1881   60        retired  married    primary      no  71188.0      no   no
#
#         contact   day month  duration  campaign  pdays  previous poutcome  \
# 3713    unknown   9.0   may     153.0       1.0   -1.0       0.0  unknown
# 3753    unknown   9.0   may     153.0       1.0   -1.0       0.0  unknown
# 9209   cellular  28.0   jul     123.0       6.0   -1.0       0.0  unknown
# 9647   cellular  28.0   jul     123.0       6.0   -1.0       0.0  unknown
# 8203   cellular   7.0   may     253.0       4.0   -1.0       0.0  unknown
# ...         ...   ...   ...       ...       ...    ...       ...      ...
# 305   telephone  15.0   jul     219.0       2.0   -1.0       0.0  unknown
# 3944    unknown  20.0   jun     174.0       3.0   -1.0       0.0  unknown
# 3697    unknown  20.0   jun     174.0       3.0   -1.0       0.0  unknown
# 1356   cellular   6.0   oct     205.0       1.0   -1.0       0.0  unknown
# 1881   cellular   6.0   oct     205.0       1.0   -1.0       0.0  unknown
#
#      Bank deposit(target)
# 3713                   no
# 3753                   no
# 9209                   no
# 9647                   no
# 8203                   no
# ...                   ...
# 305                    no
# 3944                   no
# 3697                   no
# 1356                   no
# 1881                   no
#
# [2044 rows x 17 columns]

# %%
# ASSESS OUTLIERS USING Z SCORE of 3
    # as 98% of data within 3 SD of the mean, checkin what ouliers there are
    # BALANCE column
bank_df[np.abs(stats.zscore(bank_df['balance']) > 3)] 
    ## used for visually checking data
    # one outlier identifed and should be removed
# Out:
#      age      job  marital education default     balance housing loan  \
# 231   77  retired  married   primary      no  68000000.0      no   no
#
#        contact   day month  duration  campaign  pdays  previous poutcome  \
# 231  telephone  27.0   nov     341.0       4.0   94.0       3.0  failure
#
#     Bank deposit(target)
# 231                   no

# %%
bank_df['duration']=pd.DataFrame(bank_df['duration'].apply(lambda x: x/60))

bank_df[np.abs(stats.zscore(bank_df['duration']) > 3)]
# one outlier and should be removed
# Out:
# Empty DataFrame
# Columns: [age, job, marital, education, default, balance, housing, loan, contact, day, month, duration, campaign, pdays, previous, poutcome, Bank deposit(target)]
# Index: []

# %%
# Outliers for number of campaign calls
bank_df[np.abs(stats.zscore(bank_df['campaign']) > 3)] 
    # no specific outlier identified as needing processing, but poses questions for how many times a client should be called
    # thus no action to be taken with regards to cleaning
# Out:
# Empty DataFrame
# Columns: [age, job, marital, education, default, balance, housing, loan, contact, day, month, duration, campaign, pdays, previous, poutcome, Bank deposit(target)]
# Index: []

# %%
# Outliers for pdays - numbers of days since last contact in previous campaign
bank_df[(np.abs(stats.zscore(bank_df['pdays']) > 3))]
    # dont seem unusual but could pose a question for later, i.e. should these clients be contacted as priority
    # 345 rows/clients
# Out:
# Empty DataFrame
# Columns: [age, job, marital, education, default, balance, housing, loan, contact, day, month, duration, campaign, pdays, previous, poutcome, Bank deposit(target)]
# Index: []

# %%
# Outliers for previous - numbers of contacts before this campaign
bank_df[(np.abs(stats.zscore(bank_df['previous']) > 3))]
    # dont seem unusual but could pose a question for later, i.e. what is the number of contacts the favor a succesful outcome
# Out:
#        age         job   marital  education default  balance housing loan  \
# 3       93     retired   married    unknown      no    775.0      no   no
# 4       93     retired   married    unknown      no    775.0      no   no
# 68      83   housemaid   married    primary      no   2140.0      no   no
# 108     80     retired   married  secondary      no   8304.0      no   no
# 109     80     retired   married  secondary      no   8304.0      no   no
# ...    ...         ...       ...        ...     ...      ...     ...  ...
# 11194   50  management   married   tertiary      no     78.0     yes   no
# 11204   50  technician   married   tertiary      no      0.0      no  yes
# 11215   50  technician   married   tertiary      no      0.0      no  yes
# 11216   50     unknown   married    unknown      no    558.0      no   no
# 11219   50  technician  divorced  secondary      no      0.0     yes   no
#
#          contact   day month   duration  campaign  pdays  previous poutcome  \
# 3       cellular  22.0   jul  14.333333       2.0  177.0       7.0  success
# 4       cellular   4.0   aug   7.933333       2.0   13.0       9.0  success
# 68      cellular   6.0   sep   1.816667       3.0  276.0       8.0    other
# 108    telephone   9.0   jun  11.866667       1.0   64.0      12.0  failure
# 109    telephone   6.0   apr  11.350000       1.0  118.0      11.0  success
# ...          ...   ...   ...        ...       ...    ...       ...      ...
# 11194   cellular  14.0   jan   3.633333       3.0  161.0       9.0    other
# 11204   cellular  12.0   apr   5.616667       1.0  258.0       6.0  failure
# 11215   cellular   6.0   jul   4.283333       1.0   85.0       7.0  failure
# 11216   cellular   9.0   jul   7.733333       1.0  683.0       6.0  failure
# 11219   cellular  13.0   aug   2.000000       2.0   91.0       6.0  failure
#
#       Bank deposit(target)
# 3                      yes
# 4                      yes
# 68                      no
# 108                    yes
# 109                     no
# ...                    ...
# 11194                   no
# 11204                   no
# 11215                   no
# 11216                  yes
# 11219                   no
#
# [271 rows x 17 columns]

# %%
# checking that days of the month coherent, 
bank_df['day'].max()
bank_df['day'].min()
    # between 1 and 31 which is coherent, thus no further action required
# Out:
# 1.0

# %% [markdown]
# ## Implementation of data cleaning decisions

# %%
#Changed NAN into unknown in the "education" column.
bank_df["education"] = bank_df["education"].fillna("unknown")

# %%
# Drop all duplicates in the DataFrame
bank_df = bank_df.drop_duplicates()
bank_df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       95       retired  divorced    primary      no   2282.0      no   no
# 1       95       retired   married  secondary      no      0.0      no   no
# 2       94       retired  divorced  secondary      no   1234.0      no   no
# 3       93       retired   married    unknown      no    775.0      no   no
# 4       93       retired   married    unknown      no    775.0      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 11215   50    technician   married   tertiary      no      0.0      no  yes
# 11217   50  entrepreneur  divorced   tertiary      no    315.0      no   no
# 11219   50    technician  divorced  secondary      no      0.0     yes   no
# 11220   50      services   married  secondary      no   2376.0     yes   no
# 11221   50    management   married   tertiary      no   8205.0     yes   no
#
#          contact   day month   duration  campaign  pdays  previous poutcome  \
# 0      telephone  21.0   apr   3.450000      17.0   -1.0       0.0  unknown
# 1      telephone   1.0   oct   3.583333       1.0   -1.0       0.0  unknown
# 2       cellular   3.0   mar   3.533333       1.0   -1.0       0.0  unknown
# 3       cellular  22.0   jul  14.333333       2.0  177.0       7.0  success
# 4       cellular   4.0   aug   7.933333       2.0   13.0       9.0  success
# ...          ...   ...   ...        ...       ...    ...       ...      ...
# 11215   cellular   6.0   jul   4.283333       1.0   85.0       7.0  failure
# 11217   cellular  12.0   jul   1.683333       2.0  185.0       2.0  failure
# 11219   cellular  13.0   aug   2.000000       2.0   91.0       6.0  failure
# 11220   cellular  24.0   sep   6.583333       1.0   -1.0       0.0  unknown
# 11221  telephone  25.0   oct   4.883333       3.0  508.0       1.0    other
#
#       Bank deposit(target)
# 0                      yes
# 1                       no
# 2                       no
# 3                      yes
# 4                      yes
# ...                    ...
# 11215                   no
# 11217                   no
# 11219                   no
# 11220                  yes
# 11221                   no
#
# [10194 rows x 17 columns]

# %%
def replace_w_median(bank_df):
    # find median for columns duration, campaign, pdays, and replace with mode for month
    bank_df['duration'].fillna(bank_df['duration'].median(), inplace=True)
    bank_df['campaign'].fillna(bank_df['campaign'].median(), inplace=True)
    bank_df['pdays'].fillna(bank_df['pdays'].median(), inplace=True)
    bank_df['month'].fillna(bank_df['month'].mode(),inplace=True)
replace_w_median(bank_df)
# Out:
# C:\Users\berka\AppData\Local\Temp\ipykernel_23928\2059589770.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bank_df['duration'].fillna(bank_df['duration'].median(), inplace=True)
# C:\Users\berka\AppData\Local\Temp\ipykernel_23928\2059589770.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bank_df['campaign'].fillna(bank_df['campaign'].median(), inplace=True)
# C:\Users\berka\AppData\Local\Temp\ipykernel_23928\2059589770.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bank_df['pdays'].fillna(bank_df['pdays'].median(), inplace=True)
# C:\Users\berka\AppData\Local\Temp\ipykernel_23928\2059589770.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bank_df['month'].fillna(bank_df['month'].mode(),inplace=True)

# %%
# quantiles for the pivot table
def quantile_25(bank_df:pd.Series):
    return bank_df.quantile(.25)

def quantile_75(bank_df:pd.Series):
    return bank_df.quantile(.75)

# %%
bank_df.head()
# Out:
#    age      job   marital  education default  balance housing loan    contact  \
# 0   95  retired  divorced    primary      no   2282.0      no   no  telephone
# 1   95  retired   married  secondary      no      0.0      no   no  telephone
# 2   94  retired  divorced  secondary      no   1234.0      no   no   cellular
# 3   93  retired   married    unknown      no    775.0      no   no   cellular
# 4   93  retired   married    unknown      no    775.0      no   no   cellular
#
#     day month   duration  campaign  pdays  previous poutcome  \
# 0  21.0   apr   3.450000      17.0   -1.0       0.0  unknown
# 1   1.0   oct   3.583333       1.0   -1.0       0.0  unknown
# 2   3.0   mar   3.533333       1.0   -1.0       0.0  unknown
# 3  22.0   jul  14.333333       2.0  177.0       7.0  success
# 4   4.0   aug   7.933333       2.0   13.0       9.0  success
#
#   Bank deposit(target)
# 0                  yes
# 1                   no
# 2                   no
# 3                  yes
# 4                  yes

# %%
bank_pivot=bank_df.pivot_table(values='balance', index=['Bank deposit(target)','loan'], aggfunc=[ quantile_25, np.median, quantile_75,np.max])
bank_pivot
# Out:
#                           quantile_25  median quantile_75        amax
#                               balance balance     balance     balance
# Bank deposit(target) loan
# no                   no         113.0   647.0      2026.0  68000000.0
#                      yes         14.0   314.0      1121.5     51439.0
# yes                  no         351.0  1230.0      3025.0     52587.0
#                      yes        119.0   448.0      1783.0      9103.0

# %%
#Median1 is the value for Bank deposit=no, loan=no
median1=int(bank_pivot.loc[(["no"],["no"]),(["median"],["balance"])].values[0])
#Median2 is the value for Bank deposit=yes, loan=no
median2=int(bank_pivot.loc[(["yes"],["no"]),(["median"],["balance"])].values[0])

#These filters allows us to check for multiple conditions and change the "loan" column according to these conditions with a .loc method afterwards.
filter1 = (bank_df['loan'].isna()) & (bank_df['Bank deposit(target)']=="no") & (bank_df['balance'] > median1)
bank_df.loc[filter1, "loan"] = "no"
filter2 = (bank_df['loan'].isna()) & (bank_df['Bank deposit(target)']=="no") & (bank_df['balance'] < median1)
bank_df.loc[filter2, "loan"] = "yes"
filter3 = (bank_df['loan'].isna()) & (bank_df['Bank deposit(target)']=="yes") & (bank_df['balance'] > median2)
bank_df.loc[filter3, "loan"] = "no"
filter4 = (bank_df['loan'].isna()) & (bank_df['Bank deposit(target)']=="yes") & (bank_df['balance'] < median2)
bank_df.loc[filter4, "loan"] = "yes"

# %%
pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', 20)
pd.set_option('display.width', 500)

bank_df.head(100)
# Out:
#      age      job   marital  education default  balance housing loan    contact   day month   duration  campaign  pdays  previous poutcome Bank deposit(target)
# 0     95  retired  divorced    primary      no   2282.0      no   no  telephone  21.0   apr   3.450000      17.0   -1.0       0.0  unknown                  yes
# 1     95  retired   married  secondary      no      0.0      no   no  telephone   1.0   oct   3.583333       1.0   -1.0       0.0  unknown                   no
# 2     94  retired  divorced  secondary      no   1234.0      no   no   cellular   3.0   mar   3.533333       1.0   -1.0       0.0  unknown                   no
# 3     93  retired   married    unknown      no    775.0      no   no   cellular  22.0   jul  14.333333       2.0  177.0       7.0  success                  yes
# 4     93  retired   married    unknown      no    775.0      no   no   cellular   4.0   aug   7.933333       2.0   13.0       9.0  success                  yes
# ..   ...      ...       ...        ...     ...      ...     ...  ...        ...   ...   ...        ...       ...    ...       ...      ...                  ...
# 100   81  retired   married    primary      no   5220.0      no   no  telephone  13.0   nov   2.250000       1.0   94.0       2.0    other                  yes
# 101   81  retired   married  secondary      no     93.0      no   no   cellular   7.0   dec   2.733333       1.0   -1.0       0.0  unknown                   no
# 102   81  retired  divorced  secondary      no    452.0      no   no  telephone  16.0   dec   7.383333       1.0   -1.0       0.0  unknown                  yes
# 103   81  retired  divorced   tertiary      no      0.0      no   no   cellular  14.0   jan   5.950000       1.0   -1.0       0.0  unknown                   no
# 104   81  retired   married    primary      no    243.0      no   no   cellular  27.0   jan   5.666667       1.0   92.0       1.0  success                  yes
#
# [100 rows x 17 columns]

# %%
#Fixed weird cells in education and contact
bank_df.loc[bank_df["education"]=="hjkl", "education"] = "unknown"
bank_df.loc[bank_df["contact"]=="ghjk", "contact"] = "telephone"

# %%
## we can take this out
#bank_df['outlier_bal']= np.where(bank_df['balance']> (bank_df['balance'].mean()+(bank_df['balance'].std()*3)), True,False)
#bank_df=bank_df.drop(bank_df[bank_df['outlier_bal']==True].index)

# %%
def remove_outliers(bank_df):
    
    bank_df.drop(bank_df[np.abs(stats.zscore(bank_df['balance']) > 3)==True].index, inplace=True)
    bank_df.drop(bank_df[np.abs(stats.zscore(bank_df['duration']) > 3)==True].index,inplace=True)
    

remove_outliers(bank_df)
# Out:
# C:\Users\berka\AppData\Local\Temp\ipykernel_23928\2199978985.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bank_df.drop(bank_df[np.abs(stats.zscore(bank_df['balance']) > 3)==True].index, inplace=True)
# C:\Users\berka\AppData\Local\Temp\ipykernel_23928\2199978985.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bank_df.drop(bank_df[np.abs(stats.zscore(bank_df['duration']) > 3)==True].index,inplace=True)

# %%
#Data type correction from float64 to int64.
list_of_floats_to_integer = ['day', 'duration', 'campaign', 'pdays', 'previous']

for i in list_of_floats_to_integer:
    bank_df[i] = bank_df[i].astype(np.int64)
# Out:
# C:\Users\berka\AppData\Local\Temp\ipykernel_23928\4198514806.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bank_df[i] = bank_df[i].astype(np.int64)

# %%
bank_df.to_csv('csv_export4.csv')

# %%
bank_df[bank_df['previous'].isna()]
# Out:
# Empty DataFrame
# Columns: [age, job, marital, education, default, balance, housing, loan, contact, day, month, duration, campaign, pdays, previous, poutcome, Bank deposit(target)]
# Index: []

# %%
bank_df.head()
# Out:
#    age      job   marital  education default  balance housing loan    contact  day month  duration  campaign  pdays  previous poutcome Bank deposit(target)
# 0   95  retired  divorced    primary      no   2282.0      no   no  telephone   21   apr         3        17     -1         0  unknown                  yes
# 1   95  retired   married  secondary      no      0.0      no   no  telephone    1   oct         3         1     -1         0  unknown                   no
# 2   94  retired  divorced  secondary      no   1234.0      no   no   cellular    3   mar         3         1     -1         0  unknown                   no
# 3   93  retired   married    unknown      no    775.0      no   no   cellular   22   jul        14         2    177         7  success                  yes
# 4   93  retired   married    unknown      no    775.0      no   no   cellular    4   aug         7         2     13         9  success                  yes
